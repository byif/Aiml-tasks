# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
data1.boxplot()
# Out:
# <Axes: >

# %%
data1 = np.random.randn(1000)
sns.histplot(data1, kde = True,bins = 30,color = 'blue')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = "NewspaperData.csv"  
df = pd.read_csv(file_path)
plt.figure(figsize=(8, 6))
plt.scatter(df["daily"], df["sunday"], alpha=0.7, color="blue")
plt.xlabel("Daily Circulation")
plt.ylabel("Sunday Circulation")
plt.title("Daily vs. Sunday Newspaper Circulation")
plt.grid(True)
plt.show()

# %%
data1
# Out:
# array([ 1.00892196e+00, -9.75130552e-01, -1.75256044e-01,  1.44491293e+00,
#         9.85291029e-01, -7.97520756e-01,  1.10301578e+00, -1.45697202e+00,
#        -4.10134365e-02,  1.31886191e+00, -1.96249202e+00,  6.31658925e-01,
#        -1.71512781e-01, -7.21741616e-01, -1.98912239e+00, -9.46565680e-02,
#        -1.29323913e+00,  7.56692615e-01,  1.63701237e+00, -1.45572035e+00,
#         1.72723286e+00,  1.76653872e+00,  7.61738528e-01, -1.72989762e-01,
#        -3.94238468e-01,  9.83422230e-01, -7.91511064e-01,  1.18873568e-01,
#        -2.09505328e+00,  4.87516119e-01,  2.22553345e+00, -9.49613971e-01,
#         1.13936819e-01,  1.97682997e-01,  3.28562266e-01, -1.25710537e-01,
#        -2.35714348e-01,  2.44224500e+00,  6.34048554e-01,  6.46591398e-01,
#         2.98138998e-01, -7.42282159e-01, -1.10107983e+00,  1.41594401e+00,
#        -8.79462162e-01, -3.46285099e-01,  2.14859200e-02,  3.94670088e-01,
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
data1.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data1["daily"].corr(data1["sunday"])
# Out:
# 0.9581543140785462

# %%
data1[["daily","sunday"]].corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
data1.corr(numeric_only=True)
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
plt.scatter(data1["daily"], data1["sunday"])

# %%
plt.figure(figsize=(6,3))
plt.boxplot(data1["daily"], vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a69403b260>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a694004230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a694039be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a694005130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a6940052b0>],
#  'means': []}

# %%
import seaborn as sns
sns.histplot(data1['sunday'], kde = True,stat='density',)
plt.show()
